# %% [markdown]
# # Homepage Data Preprocessing Notebook

# %% [markdown]
# ## 1. Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Load Data and Preprocessing

# %%
# Define data path
DATA_PATH = "./data"
GAME_DATA = DATA_PATH + "/games.csv"

# %%
# Load and check data
df = pd.read_csv(GAME_DATA)
df.head(3)
# Out:
#      AppID              Name  Release date Estimated owners  Peak CCU  \
# 0    20200  Galactic Bowling  Oct 21, 2008        0 - 20000         0
# 1   655370      Train Bandit  Oct 12, 2017        0 - 20000         0
# 2  1732930      Jolt Project  Nov 17, 2021        0 - 20000         0
#
#    Required age  Price  DLC count  \
# 0             0  19.99          0
# 1             0   0.99          0
# 2             0   4.99          0
#
#                                       About the game  \
# 0  Galactic Bowling is an exaggerated and stylize...
# 1  THE LAW!! Looks to be a showdown atop a train....
# 2  Jolt Project: The army now has a new robotics ...
#
#                                  Supported languages  ...  \
# 0                                        ['English']  ...
# 1  ['English', 'French', 'Italian', 'German', 'Sp...  ...
# 2                 ['English', 'Portuguese - Brazil']  ...
#
#   Average playtime two weeks Median playtime forever  \
# 0                          0                       0
# 1                          0                       0
# 2                          0                       0
#
#   Median playtime two weeks             Developers             Publishers  \
# 0                         0  Perpetual FX Creative  Perpetual FX Creative
# 1                         0           Rusty Moyher           Wild Rooster
# 2                         0          Campião Games          Campião Games
#
#                                           Categories  \
# 0  Single-player,Multi-player,Steam Achievements,...
# 1  Single-player,Steam Achievements,Full controll...
# 2                                      Single-player
#
#                             Genres  \
# 0              Casual,Indie,Sports
# 1                     Action,Indie
# 2  Action,Adventure,Indie,Strategy
#
#                                                 Tags  \
# 0                        Indie,Casual,Sports,Bowling
# 1  Indie,Action,Pixel Graphics,2D,Retro,Arcade,Sc...
# 2                                                NaN
#
#                                          Screenshots  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                               Movies
# 0  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 1  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 2  http://cdn.akamai.steamstatic.com/steam/apps/2...
#
# [3 rows x 39 columns]

# %%
og_cols = df.columns
col_mapping = dict(zip(og_cols, ["_".join(col.lower().split()) for col in og_cols]))
df = df.rename(columns=col_mapping)
df.head(3)
# Out:
#      appid              name  release_date estimated_owners  peak_ccu  \
# 0    20200  Galactic Bowling  Oct 21, 2008        0 - 20000         0
# 1   655370      Train Bandit  Oct 12, 2017        0 - 20000         0
# 2  1732930      Jolt Project  Nov 17, 2021        0 - 20000         0
#
#    required_age  price  dlc_count  \
# 0             0  19.99          0
# 1             0   0.99          0
# 2             0   4.99          0
#
#                                       about_the_game  \
# 0  Galactic Bowling is an exaggerated and stylize...
# 1  THE LAW!! Looks to be a showdown atop a train....
# 2  Jolt Project: The army now has a new robotics ...
#
#                                  supported_languages  ...  \
# 0                                        ['English']  ...
# 1  ['English', 'French', 'Italian', 'German', 'Sp...  ...
# 2                 ['English', 'Portuguese - Brazil']  ...
#
#   average_playtime_two_weeks median_playtime_forever  \
# 0                          0                       0
# 1                          0                       0
# 2                          0                       0
#
#   median_playtime_two_weeks             developers             publishers  \
# 0                         0  Perpetual FX Creative  Perpetual FX Creative
# 1                         0           Rusty Moyher           Wild Rooster
# 2                         0          Campião Games          Campião Games
#
#                                           categories  \
# 0  Single-player,Multi-player,Steam Achievements,...
# 1  Single-player,Steam Achievements,Full controll...
# 2                                      Single-player
#
#                             genres  \
# 0              Casual,Indie,Sports
# 1                     Action,Indie
# 2  Action,Adventure,Indie,Strategy
#
#                                                 tags  \
# 0                        Indie,Casual,Sports,Bowling
# 1  Indie,Action,Pixel Graphics,2D,Retro,Arcade,Sc...
# 2                                                NaN
#
#                                          screenshots  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                               movies
# 0  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 1  http://cdn.akamai.steamstatic.com/steam/apps/2...
# 2  http://cdn.akamai.steamstatic.com/steam/apps/2...
#
# [3 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['appid', 'name', 'release_date', 'estimated_owners', 'peak_ccu',
#        'required_age', 'price', 'dlc_count', 'about_the_game',
#        'supported_languages', 'full_audio_languages', 'reviews',
#        'header_image', 'website', 'support_url', 'support_email', 'windows',
#        'mac', 'linux', 'metacritic_score', 'metacritic_url', 'user_score',
#        'positive', 'negative', 'score_rank', 'achievements', 'recommendations',
#        'notes', 'average_playtime_forever', 'average_playtime_two_weeks',
#        'median_playtime_forever', 'median_playtime_two_weeks', 'developers',
#        'publishers', 'categories', 'genres', 'tags', 'screenshots', 'movies'],
#       dtype='object')

# %%
col_to_keep = ['name', 'estimated_owners', 'peak_ccu', 'price', 'positive', 'negative', 'average_playtime_two_weeks', 'genres']

# %%
filtered_df = df[col_to_keep]
filtered_df.head(3)
# Out:
#                name estimated_owners  peak_ccu  price  positive  negative  \
# 0  Galactic Bowling        0 - 20000         0  19.99         6        11
# 1      Train Bandit        0 - 20000         0   0.99        53         5
# 2      Jolt Project        0 - 20000         0   4.99         0         0
#
#    average_playtime_two_weeks                           genres
# 0                           0              Casual,Indie,Sports
# 1                           0                     Action,Indie
# 2                           0  Action,Adventure,Indie,Strategy

# %%
# drop the rows where average_playtime_two_weeks is 0 
#filtered_df = filtered_df[filtered_df['average_playtime_two_weeks'] != 0]
#filtered_df.head(3)

# %%
filtered_df[["estimated_owners_low", "estimated_owners_high"]] = filtered_df["estimated_owners"].str.split(" - ", n=1, expand=True)
filtered_df.drop(["estimated_owners"], axis=1, inplace=True)
filtered_df["estimated_owners"] = (filtered_df["estimated_owners_low"].astype(int) + filtered_df["estimated_owners_high"].astype(int)) / 2
filtered_df.drop(["estimated_owners_low", "estimated_owners_high"], axis=1, inplace=True)
filtered_df
# Out:
# C:\Users\Anime\AppData\Local\Temp\ipykernel_25292\2340476138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[["estimated_owners_low", "estimated_owners_high"]] = filtered_df["estimated_owners"].str.split(" - ", n=1, expand=True)
# C:\Users\Anime\AppData\Local\Temp\ipykernel_25292\2340476138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[["estimated_owners_low", "estimated_owners_high"]] = filtered_df["estimated_owners"].str.split(" - ", n=1, expand=True)
# C:\Users\Anime\AppData\Local\Temp\ipykernel_25292\2340476138.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop(["estimated_owners"], axis=1, inplace=True)
# C:\Users\Anime\AppData\Local\Temp\ipykernel_25292\2340476138.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["estimated_owners"] = (filtered_df["estimated_owners_low"].astype(int) + filtered_df["estimated_owners_high"].astype(int)) / 2
# C:\Users\Anime\AppData\Local\Temp\ipykernel_25292\2340476138.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop(["estimated_owners_low", "estimated_owners_high"], axis=1, inplace=True)
#                           name  peak_ccu  price  positive  negative  \
# 0             Galactic Bowling         0  19.99         6        11
# 1                 Train Bandit         0   0.99        53         5
# 2                 Jolt Project         0   4.99         0         0
# 3                     Henosis™         0   5.99         3         0
# 4        Two Weeks in Painland         0   0.00        50         8
# ...                        ...       ...    ...       ...       ...
# 85098  Mannerheim's Saloon Car         0   0.00         0         0
# 85099                 Beer Run         0   0.00         0         0
# 85100     My Friend The Spider         0   0.00         0         0
# 85101        Path of Survivors         0   3.99         0         0
# 85102          The Night Heist         0   9.99         0         0
#
#        average_playtime_two_weeks                              genres  \
# 0                               0                 Casual,Indie,Sports
# 1                               0                        Action,Indie
# 2                               0     Action,Adventure,Indie,Strategy
# 3                               0              Adventure,Casual,Indie
# 4                               0                     Adventure,Indie
# ...                           ...                                 ...
# 85098                           0                Adventure,Simulation
# 85099                           0                        Casual,Indie
# 85100                           0                Adventure,Simulation
# 85101                           0  Action,Casual,Indie,RPG,Simulation
# 85102                           0                        Casual,Indie
#
#        estimated_owners
# 0               10000.0
# 1               10000.0
# 2               10000.0
# 3               10000.0
# 4               10000.0
# ...                 ...
# 85098               0.0
# 85099               0.0
# 85100               0.0
# 85101               0.0
# 85102               0.0
#
# [85103 rows x 8 columns]

# %%
filtered_df = filtered_df.assign(genres=df["genres"].str.split(',')).explode("genres")
genre_counts = filtered_df.groupby(["name", "genres"]).size().reset_index(name="count")

# %%
filtered_df.head(10)
# Out:
#                name  peak_ccu  price  positive  negative  \
# 0  Galactic Bowling         0  19.99         6        11
# 0  Galactic Bowling         0  19.99         6        11
# 0  Galactic Bowling         0  19.99         6        11
# 1      Train Bandit         0   0.99        53         5
# 1      Train Bandit         0   0.99        53         5
# 2      Jolt Project         0   4.99         0         0
# 2      Jolt Project         0   4.99         0         0
# 2      Jolt Project         0   4.99         0         0
# 2      Jolt Project         0   4.99         0         0
# 3          Henosis™         0   5.99         3         0
#
#    average_playtime_two_weeks     genres  estimated_owners
# 0                           0     Casual           10000.0
# 0                           0      Indie           10000.0
# 0                           0     Sports           10000.0
# 1                           0     Action           10000.0
# 1                           0      Indie           10000.0
# 2                           0     Action           10000.0
# 2                           0  Adventure           10000.0
# 2                           0      Indie           10000.0
# 2                           0   Strategy           10000.0
# 3                           0  Adventure           10000.0

# %%
genre_counts
# Out:
#                                                 name        genres  count
# 0                                      ! Shakabula *        Action      1
# 1                                      ! Shakabula *  Early Access      1
# 2                                      ! Shakabula *         Indie      1
# 3                                      ! Shakabula *           RPG      1
# 4       ! That Bastard Is Trying To Steal Our Gold !        Action      1
# ...                                              ...           ...    ...
# 232029                              🧠 OUT OF THE BOX    Simulation      1
# 232030                              🧠 OUT OF THE BOX      Strategy      1
# 232031                                             𣸩     Adventure      1
# 232032                                             𣸩        Casual      1
# 232033                                             𣸩         Indie      1
#
# [232034 rows x 3 columns]

# %%
genre_counts_aggregated = genre_counts.groupby('genres')['count'].sum().reset_index(name='total_count')
sorted_genres = genre_counts_aggregated.sort_values(by='total_count', ascending=False)

# %%
top_to_genres = sorted_genres.head(10)
top_to_genres
# Out:
#           genres  total_count
# 15         Indie        56929
# 6         Casual        34208
# 2         Action        33808
# 3      Adventure        31450
# 24    Simulation        16146
# 27      Strategy        15602
# 20           RPG        14439
# 9   Early Access        10403
# 12  Free to Play         6630
# 26        Sports         3790

# %%
top_10_genre =top_to_genres['genres'].values
filtered_df_further = filtered_df[filtered_df['genres'].isin(top_10_genre)]

# %%
filtered_df_further
# Out:
#                     name  peak_ccu  price  positive  negative  \
# 0       Galactic Bowling         0  19.99         6        11
# 0       Galactic Bowling         0  19.99         6        11
# 0       Galactic Bowling         0  19.99         6        11
# 1           Train Bandit         0   0.99        53         5
# 1           Train Bandit         0   0.99        53         5
# ...                  ...       ...    ...       ...       ...
# 85101  Path of Survivors         0   3.99         0         0
# 85101  Path of Survivors         0   3.99         0         0
# 85101  Path of Survivors         0   3.99         0         0
# 85102    The Night Heist         0   9.99         0         0
# 85102    The Night Heist         0   9.99         0         0
#
#        average_playtime_two_weeks      genres  estimated_owners
# 0                               0      Casual           10000.0
# 0                               0       Indie           10000.0
# 0                               0      Sports           10000.0
# 1                               0      Action           10000.0
# 1                               0       Indie           10000.0
# ...                           ...         ...               ...
# 85101                           0       Indie               0.0
# 85101                           0         RPG               0.0
# 85101                           0  Simulation               0.0
# 85102                           0      Casual               0.0
# 85102                           0       Indie               0.0
#
# [223421 rows x 8 columns]

# %%
filtered_df_further["user_score"] = (filtered_df_further["positive"] / (filtered_df_further["positive"] + filtered_df_further["negative"]) * 100).round(2)
filtered_df_further = filtered_df_further.drop(columns=["positive", "negative", "average_playtime_two_weeks"])
filtered_df_further["user_score"] = filtered_df_further["user_score"].fillna(0)
filtered_df_further
# Out:
# C:\Users\Anime\AppData\Local\Temp\ipykernel_25292\2917657828.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_further["user_score"] = (filtered_df_further["positive"] / (filtered_df_further["positive"] + filtered_df_further["negative"]) * 100).round(2)
#                     name  peak_ccu  price      genres  estimated_owners  \
# 0       Galactic Bowling         0  19.99      Casual           10000.0
# 0       Galactic Bowling         0  19.99       Indie           10000.0
# 0       Galactic Bowling         0  19.99      Sports           10000.0
# 1           Train Bandit         0   0.99      Action           10000.0
# 1           Train Bandit         0   0.99       Indie           10000.0
# ...                  ...       ...    ...         ...               ...
# 85101  Path of Survivors         0   3.99       Indie               0.0
# 85101  Path of Survivors         0   3.99         RPG               0.0
# 85101  Path of Survivors         0   3.99  Simulation               0.0
# 85102    The Night Heist         0   9.99      Casual               0.0
# 85102    The Night Heist         0   9.99       Indie               0.0
#
#        user_score
# 0           35.29
# 0           35.29
# 0           35.29
# 1           91.38
# 1           91.38
# ...           ...
# 85101        0.00
# 85101        0.00
# 85101        0.00
# 85102        0.00
# 85102        0.00
#
# [223421 rows x 6 columns]

# %%
filtered_df_further.to_csv(DATA_PATH + "/homePageBroadData.csv", index=False)

# %% [markdown]
# ## Option 2 for Data Preprocessing

# %%
genre_df = df.assign(genres=df["genres"].str.split(',')).explode("genres")

genre_df[["estimated_owners_low", "estimated_owners_high"]] = genre_df["estimated_owners"].str.split(" - ", n=1, expand=True)
genre_df.drop(["estimated_owners"], axis=1, inplace=True)
genre_df["estimated_owners"] = (genre_df["estimated_owners_low"].astype(int) + genre_df["estimated_owners_high"].astype(int)) / 2
genre_df.drop(["estimated_owners_low", "estimated_owners_high"], axis=1, inplace=True)
genre_df

genre_counts = genre_df.groupby(['name', 'estimated_owners', 'peak_ccu', 'price', 'positive', 'negative', 'average_playtime_two_weeks', 'genres']).size().reset_index(name="count")

# %%
genre_counts_aggregated = genre_counts.groupby('genres')['count'].sum().reset_index(name='game_count')
sorted_genres = genre_counts_aggregated.sort_values(by='game_count', ascending=False)
top_10_genres = sorted_genres.head(10)

# %%
top_10_genres
# Out:
#           genres  game_count
# 15         Indie       56929
# 6         Casual       34208
# 2         Action       33808
# 3      Adventure       31450
# 24    Simulation       16146
# 27      Strategy       15602
# 20           RPG       14439
# 9   Early Access       10403
# 12  Free to Play        6630
# 26        Sports        3790

# %%
genre_filtered = genre_counts[genre_counts["genres"].isin(top_10_genres["genres"].values)]

# %%
genre_filtered.head(1)
# Out:
#             name  estimated_owners  peak_ccu  price  positive  negative  \
# 0  ! Shakabula *           10000.0         0  14.99         1         1
#
#    average_playtime_two_weeks  genres  count
# 0                           0  Action      1

# %%
genre_filtered_aggregated = genre_filtered.groupby('genres')['count'].sum().reset_index(name='game_count')
sorted_filtered_genres = genre_filtered_aggregated.sort_values(by='game_count', ascending=False)
top_10_filtered_genres = sorted_filtered_genres.head(10)

# %% [markdown]
# ## To be continued!

# %% [markdown]
# For each genre, need:
# - Number of games
# - List of estimated owners, one entry per game within the genre
# - Same but for peak_ccu
# - Same but for price
# - Same but for positive/negative
#
# Therefore, for now, it's skipped, as putting one row per genre is easier to do here and manage in JS. Might come back to this.

# %% [markdown]
# ### Never came back to this :( It still works though!
